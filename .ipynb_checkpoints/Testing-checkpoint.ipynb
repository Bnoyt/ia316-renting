# %%
from utils import *
from environnement import Environnement
from policies import Policy,RandomPolicy,SmarterRandomPolicy
from tester import Tester
pd.options.mode.chained_assignment = None  # default='warn'

# %%
env_params = {
    'experiment_length':1000,
    "n_users":30,
    "n_clusters":5,
    'dim':10,
    "n_bikes_per_user":1,
    "users_per_day":10
}
env = Environnement(env_params,2)
policies = [RandomPolicy({"list_length":5,"price":i},3) for i in [100,500,1000,2000]]
policies = [RandomPolicy({"list_length":1,"price":500},3),SmarterRandomPolicy({"list_length":5,"price":500},3)]

# %%
params = {
    'n_steps':50,
    "n_rep":20
}

# %%
tester = Tester(policies,env,params)

# %%
tester.run()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Testing policy |RandomPolicy_500|
# /home/bnoyt/MEGAsync/Télécom/IA316 AI and e-commerce/ia316-renting/environnement.py:133: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   self.history = pd.concat([self.history,history_to_append])
# 100%|██████████| 20/20 [00:21<00:00,  1.01s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Testing policy |SmarterRandomPolicy_500|
# 100%|██████████| 20/20 [00:20<00:00,  1.00s/it]

# %%
tester.plotAllPoliciesQuantiles()

# %%
tester.plotAllPoliciesCompared()
