# %%
from utils import *

# %%
from environnement import Environnement

# %%
from policies import Policy

# %%
class RandomPolicy(Policy):
    def __init__(self,params,seed):
        self.params = params
        self.seed = seed
        self.list_length = self.params["list_length"]
        self.init()
        
        self.__name__ = f"RandomPolicy_{params['price']}"
        
    def get_action(self,context):
        
        indexes = np.array([i for i in range(len(context["bikes_available"]))])
        
        self.rng.shuffle(indexes)
        
        
        bikes_available = [context["bikes_available"][i] for i in indexes]
        bikes_availability = [context['bikes_availability'][i] for i in indexes]
        prices = [self.params["price"] for i in indexes]
        
        return bikes_available[:self.list_length],bikes_availability[:self.list_length],prices[:self.list_length]

# %%
class Tester(object):
    def __init__(self,policies,env,params):
        self.params = params
        self.n_steps = params["n_steps"]
        self.n_rep = params["n_rep"]
        
        self.history = {p.__name__:[] for p in policies}
        self.policies = policies
        self.env = env
        self.ran = False
        
        
    def run(self):
                
        for policy in self.policies:
            print( f"Testing policy |{policy.__name__}|")
        
            for j in tqdm(range(self.n_rep)):

                env.init(j)
                policy.init()

                for i in range(self.n_steps):
                    context = env.get_context()
                    b,d,p = policy.get_action(context)
                    result = env.act(b,d,p)

                self.history[policy.__name__].append(env.get_history())
                
        self.ran = True
                
    def plotByPolicy(self,policy_name):
        
        assert policy_name in self.history, "Policy name unknown"
        assert self.ran, "You must run the test by tester.run() before plotting results"
        
        dfs = self.history[policy_name]
        
        regrets = np.array([(df.best_reward - df.reward).cumsum().values for df in dfs])

        regret = np.array([(df.best_reward - df.reward).values for df in dfs])
        
        plt.figure(figsize=(15,7))
        plt.style.use("bmh")
        plt.plot(regrets.mean(axis=0), color='blue')
        plt.plot(np.quantile(regrets, 0.05,axis=0), color='grey', alpha=0.5)
        plt.plot(np.quantile(regrets, 0.95,axis=0), color='grey', alpha=0.5)
        plt.title('Mean regret: {:.2f} for {}'.format(regret.mean(),policy_name))
        plt.xlabel('steps')
        plt.ylabel('regret')
        plt.show()
        
    def plotAllPolicies(self):
        for n in self.history:
            self.plotByPolicy(n)

# %%
env_params = {
    'experiment_length':365,
    "n_users":100,
    "n_clusters":5,
    'dim':10,
    "n_bikes_per_user":1,
    "users_per_day":10
}
env = Environnement(env_params,2)
policy = RandomPolicy({"list_length":5,"price":100},3)

# %%
params = {
    'n_steps':50,
    "n_rep":20
}

# %%
tester = Tester([policy],env,params)

# %%
tester.run()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Testing policy |RandomPolicy_100|
# /home/bnoyt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/bnoyt/MEGAsync/Télécom/IA316 AI and e-commerce/ia316-renting/environnement.py:133: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   self.history = pd.concat([self.history,history_to_append])
# 100%|██████████| 20/20 [01:07<00:00,  3.27s/it]

# %%
tester.plotAllPolicies()

# %%
n_steps = 100
n_rep = 20
plt.style.use("bmh")
plt.figure(figsize=(15,7))

dfs = []

params = {
    'experiment_length':365,
    "n_users":100,
    "n_clusters":5,
    'dim':10,
    "n_bikes_per_user":1,
    "users_per_day":10
}
seed = 2
env = Environnement(params,seed)

env.init()

policy = RandomPolicy({"list_length":5,"price":100},3)
for j in range(n_rep):
    env = Environnement(params,j)
    policy = RandomPolicy({"list_length":5,"price":100},j)
    env.init()
    for i in tqdm(range(n_steps)):
        context = env.get_context()
        b,d,p = policy.get_action(context)
        result = env.act(b,d,p)

    dfs.append(env.get_history())
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/home/bnoyt/MEGAsync/Télécom/IA316 AI and e-commerce/ia316-renting/environnement.py:133: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   self.history = pd.concat([self.history,history_to_append])
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]/home/bnoyt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# ...
# 100%|██████████| 100/100 [00:05<00:00, 18.15it/s]

# %%
regrets = np.array([(df.best_reward - df.reward).cumsum().values for df in dfs])

regret = np.array([(df.best_reward - df.reward).values for df in dfs])

# %%
plt.figure(figsize=(15,7))
plt.style.use("bmh")
plt.plot(regrets.mean(axis=0), color='blue')
plt.plot(np.quantile(regrets, 0.05,axis=0), color='grey', alpha=0.5)
plt.plot(np.quantile(regrets, 0.95,axis=0), color='grey', alpha=0.5)
plt.title('Mean regret: {:.2f}'.format(regret.mean()))
plt.xlabel('steps')
plt.ylabel('regret')
plt.show()
